# %%
import shapefile
 
sf = shapefile.Reader("/home/santiago/sebas/geodata/Codgeo_Pais_x_prov_datos/pxpciadatosok.shp")
#dbf = shapefile.Reader("/home/santiago/sebas/geodata/Codgeo_Pais_x_prov_datos/pxpciadatosok.dbf")

# %%
print(sf.shapeType)
print(len(sf))

sf.shapeTypeName
# Out:
# 5
# 24
# 'POLYGON'

# %%
# shape guarda la geometría

# records guarda los atributos
# Out:
# [('DeletionFlag', 'C', 1, 0),
#  ['link', 'C', 254, 0],
#  ['provincia', 'C', 254, 0],
#  ['mujeres', 'C', 21, 0],
#  ['varones', 'C', 21, 0],
#  ['personas', 'C', 21, 0],
#  ['hogares', 'C', 21, 0],
#  ['viv_part', 'C', 21, 0],
#  ['viv_part_h', 'C', 21, 0]]

# %%
dir(sf.shape(7))
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__geo_interface__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_from_geojson',
#  'bbox',
#  'parts',
#  'points',
#  'shapeType',
#  'shapeTypeName']

# %%
for name in dir(sf.shape(3)):
    if not name.startswith('_'):
        print(name)
print('bbox',sf.shape(3).bbox)
print('parts',sf.shape(3).parts)
print('points',sf.shape(3).points)
print('shape type number', sf.shape(3).shapeType)
print('shape type name', sf.shape(3).shapeTypeName)
# Out:
# bbox
# parts
# points
# shapeType
# shapeTypeName
# bbox [-59.71352457, -30.72632164, -55.62006659, -27.26021637]
# parts [0]
# ...

# %%
sf.shape(3)

# sf.shape(3) es un objeto
# sf.record(3) es una lista

# %%
sf.fields
# Out:
# [('DeletionFlag', 'C', 1, 0),
#  ['link', 'C', 254, 0],
#  ['provincia', 'C', 254, 0],
#  ['mujeres', 'C', 21, 0],
#  ['varones', 'C', 21, 0],
#  ['personas', 'C', 21, 0],
#  ['hogares', 'C', 21, 0],
#  ['viv_part', 'C', 21, 0],
#  ['viv_part_h', 'C', 21, 0]]

# %%
sf.record(3) # son los atributos correspondientes a la geometría 3: sf.shape(3)
# Out:
# Record #3: ['18', 'Corrientes', '507520', '485075', '992595', '267797', '292644', '248844']

# %%
sf.record(3)['provincia']
# Out:
# 'Corrientes'

# %%
sf.record(3)[0:4]
# Out:
# ['18', 'Corrientes', '507520', '485075']

# %%
sf.record(3).as_dict() # se puede convertir un record a diccionario
# Out:
# {'link': '18',
#  'provincia': 'Corrientes',
#  'mujeres': '507520',
#  'varones': '485075',
#  'personas': '992595',
#  'hogares': '267797',
#  'viv_part': '292644',
#  'viv_part_h': '248844'}

# %%
shapeRecs = sf.shapeRecords() # recupera ambas, atributos y geometría, mediante atributos 'shape' y 'record'
# se usa parecio a antes luego de seleccionar el atributo shape o record

print(shapeRecs[4].shape.bbox)
print(shapeRecs[4].record)
# Out:
# [-63.42364003, -28.06538357, -58.37863489, -24.08280635]
# Record #4: ['22', 'Chaco', '535309', '519950', '1055259', '288422', '312602', '270133']

# %%
json_collec = shapeRecs.__geo_interface__['type'] # convierte a GeoJSON
dir(json_collec)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...
